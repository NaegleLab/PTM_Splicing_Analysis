# %% [markdown]
# # Generating Figures for Manuscript

# %% [markdown]
# ## Table of Contents
#
# 1. [Load Data](#load-data)
# 2. Main Figures
#     1. [Figure 1](#figure-1)
#     2. [Figure 2](#figure-2)
#     3. [Figure 3](#figure-3)
#     4. [Figure 4](#figure-4)
# 3. Supplementary Figures
#     1. [Supplementary Figure 2](#supplementary-figure-2)
#     2. [Supplementary Figure 4](#supplementary-figure-4)
#     3. [Supplementary Figure 5](#supplementary-figure-5)
#     4. [Supplementary Figure 6](#supplementary-figure-6)
#     5. [Supplementary Figure 7](#supplementary-figure-7)
#     6. [Supplementary Figure 8](#supplementary-figure-8)
#     7. [Supplementary Figure 9](#supplementary-figure-9)
#     8. [Supplementary Figure 10](#supplementary-figure-10)
#     9. [Supplementary Figure 11](#supplementary-figure-11)
#     10. [Supplementary Figure 12](#supplementary-figure-12)
#     11. [Supplementary Figure 13](#supplementary-figure-13)
#     12. [Supplementary Figure 14](#supplementary-figure-14)
#     13. [Supplementary Figure 15](#supplementary-figure-15)
#     14. [Supplementary Figure 16](#supplementary-figure-16)

# %% [markdown]
# ## Load Data

# %%
import matplotlib.pyplot as plt


import generate_figures


#indicate location of figshare files
#location of figshare data
figshare_dir = 'C:/Users/Sam/OneDrive/Documents/GradSchool/Research/Splicing/Paper_Prep/PTM_Splicing_FigShare/'
#where to find projected PTMs
ptm_data_dir = figshare_dir + 'PTM_Projection_Data/'
#where to find information from different databases
database_dir = figshare_dir + 'External_Data/'
#where analysis data will be saved
analysis_dir = figshare_dir + 'Analysis_For_Paper/'


data = generate_figures.FigureData(figshare_dir=figshare_dir)
# Out:
# c:\Users\Sam\miniconda3\envs\splice\Lib\site-packages\Bio\pairwise2.py:278: BiopythonDeprecationWarning: Bio.pairwise2 has been deprecated, and we intend to remove it in a future release of Biopython. As an alternative, please consider using Bio.Align.PairwiseAligner as a replacement, and contact the Biopython developers if you still need the Bio.pairwise2 module.
#   warnings.warn(
# Downloading ID translator file
# Loading mapper object from .tsv files
# Loading exon-specific data
# Loading transcript-specific data
# Loading gene-specific info
# Loading unique protein isoforms
# Loading protein-specific info
# Loading information on PTMs on canonical proteins
# Loading genomic coordinates of PTMs associated with canonical proteins
# Loading information on PTMs on alternative proteins
# c:\Users\Sam\OneDrive\Documents\GradSchool\Research\Splicing\Paper_Prep\PTM_Splicing_Analysis\PaperFigures\generate_figures.py:64: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   mapper.isoform_ptms = pd.read_csv(self.ptm_data_dir + '/processed_data_dir/isoform_ptms.csv')

# %% [markdown]
# ## Figure 2
#
# [Return to Table of Contents](#table-of-contents)

# %%
figure2 = generate_figures.Figure2(data)
figure2.generate_figure()

# %% [markdown]
# ## Figure 3
#
# [Return to Table of Contents](#table-of-contents)

# %%
figure3 = generate_figures.Figure3(data)

# %% [markdown]
# ### Panel B

# %%
fig, ax = plt.subplots(figsize = (4,0.5))
figure3.PanelB(ax = ax, leg_loc = (0.0, 1.8))

# %% [markdown]
# ### Panel C

# %%
fig, ax = plt.subplots(figsize = (2.5,2.5))
figure3.PanelC(ax = ax, leg_loc = [0.02, 0.45])
# Out:
# Making Figure 3C

# %% [markdown]
# ### Panel D

# %%
figure3.PanelD()
# Out:
# Plotting Figure 3D

# %% [markdown]
# ### Panel E

# %%
figure3.PanelE()
# Out:
# Making Figure3E

# %% [markdown]
# ### Panel F

# %%
figure3.PanelF()
# Out:
# Making Figure 3F

# %% [markdown]
# ### Panel G part 1

# %%
figure3.PanelG()
# Out:
# Making Figure 3G
# c:\Users\Sam\miniconda3\envs\splice\Lib\site-packages\matplotlib\transforms.py:2038: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   self._mtx[0, 2] += tx
# c:\Users\Sam\miniconda3\envs\splice\Lib\site-packages\matplotlib\text.py:1461: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   x = float(self.convert_xunits(x))
# c:\Users\Sam\miniconda3\envs\splice\Lib\site-packages\matplotlib\text.py:753: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   posx = float(self.convert_xunits(self._x))
# c:\Users\Sam\miniconda3\envs\splice\Lib\site-packages\matplotlib\text.py:894: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   x = float(self.convert_xunits(self._x))

# %% [markdown]
# ### Panel G part 2

# %%
figure3.PanelH()
# Out:
# Making Figure 3H

# %% [markdown]
# ## Figure 4
#
# [Return to Table of Contents](#table-of-contents)

# %%
figure4 = generate_figures.Figure4(data)

# %% [markdown]
# ### Panel A

# %%
figure4.PanelA()

# %% [markdown]
# ### Panel B

# %%
figure4.PanelB()

# %% [markdown]
# ### Panel C

# %%
figure4.PanelC()

# %% [markdown]
# ### Panel D

# %%
figure4.PanelD()

# %% [markdown]
# ## Supplementary Figure 2
#
# PTMs that are annotated in the canonical UniProt isoform versus the alternative isoform.
#
# [Return to Table of Contents](#table-of-contents)

# %%
sfig2 = generate_figures.SupplementaryFigure2(data)
sfig2.generate_figure()

# %%
sfig2.getMappingSuccess()
# Out:
# Fraction of PTMs associated with UniProt Isoform that are captured by mapping process: 0.798300504870938
# Fraction of PTMs captured by mapping process that are not found associated with UniProt isoform: 0.9622623433550261

# %% [markdown]
# ## Supplementary Figure 4
#
# Relationship between PTM density and consitutive exons.
#
# [Return to Table of Contents](#table-of-contents)

# %%
sfig4 = generate_figures.SupplementaryFigure4(data)
sfig4.generate_figure()

# %% [markdown]
# ## Supplementary Figure 5
#
# All constitutive rates for broad modification classes, as long as there is at least one instance in the human proteome.
#
# [Return to Table of Contents](#table-of-contents)

# %%
sfig5 = generate_figures.SupplementaryFigure5(data)
sfig5.generate_figure()

# %% [markdown]
# ## Supplementary Figure 6
#
# Relationship between constitutive rate and location of PTMs in domains.
#
# [Return to Table of Contents](#table-of-contents)

# %%
sfig6 = generate_figures.SupplementaryFigure6(data)
sfig6.generate_figure()

# %% [markdown]
# ## Supplementary Figure 7
#
# Constitutive rates for modification subtypes (phosphotyrosine, phosphoserine, and phosphothreonine for phsophorylation, for example).
#
# [Return to Table of Contents](#table-of-contents)

# %%
sfig8 = generate_figures.SupplementaryFigure7(data)
sfig8.generate_figure()

# %% [markdown]
# ## Supplementary Figure 8
#
# Constitutive rates of PTMs after using various types of functional filtering. Goal is to account for possible protein-coding transcripts may not code for functional protein.
#
# [Return to Table of Contents](#table-of-contents)

# %%
sfig8 = generate_figures.SupplementaryFigure8(data)
sfig8.generate_figure()
# Out:
# c:\Users\Sam\OneDrive\Documents\GradSchool\Research\Splicing\Paper_Prep\PTM_Splicing_Analysis\PaperFigures\generate_figures.py:1650: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   def PanelC(self, ax = None, data_save_dir = None, fig_save_dir = None):

# %% [markdown]
# ## Supplementary Figure 9
#
# Biological and molecular function enrichment for constitutive and non-constitutive PTMs.
#
# [Return to Table of Contents](#table-of-contents)

# %%
sfig9 = generate_figures.SupplementaryFigure9(data)
sfig9.generate_figure()

# %% [markdown]
# ## Supplementary Figure 10
#
# How mutually exclusive exons impact PTMs.
#
# [Return to Table of Contents](#table-of-contents)

# %%
sfig10 = generate_figures.SupplementaryFigure10(data)

# %% [markdown]
# ### Panel B

# %%
sfig10.PanelB()
# Out:
# c:\Users\Sam\OneDrive\Documents\GradSchool\Research\Splicing\Paper_Prep\PTM_Splicing_Analysis\PaperFigures\generate_figures.py:1885: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation = 35, ha = 'right', fontsize = self.data.axes_label_size-1)
# c:\Users\Sam\OneDrive\Documents\GradSchool\Research\Splicing\Paper_Prep\PTM_Splicing_Analysis\PaperFigures\generate_figures.py:1895: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticklabels(), fontsize = self.data.axes_label_size-1)

# %% [markdown]
# ### Panel C

# %%
sfig10.PanelC()

# %% [markdown]
# ## Supplementary Figure 11
#
# Deeper analysis of altered flanking sequences between canonical and alternative isoforms.
#
# [Return to Table of Contents](#table-of-contents)

# %%
sfig11 = generate_figures.SupplementaryFigure11(data)
sfig11.generate_figure()
# Out:
# c:\Users\Sam\OneDrive\Documents\GradSchool\Research\Splicing\Paper_Prep\PTM_Splicing_Analysis\PaperFigures\generate_figures.py:2168: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[0].set_xticklabels(['N-term\nonly', 'C-term\nonly', 'Both'])

# %% [markdown]
# ## Supplementary Figure 12
#
# Gene set enrichment analysis of ESRP1-regulated genes.
#
# [Return to Table of Contents](#table-of-contents)

# %%
sfig13 = generate_figures.SupplementaryFigure12(data)
sfig13.plot_all_sets()

# %% [markdown]
# ## Supplementary Figure 13
#
# PTMs that are regulated by ESRP1 in prostate cancer and their functions.
#
# [Return to Table of Contents](#table-of-contents)

# %%
sfig13 = generate_figures.SupplementaryFigure13(data)
sfig13.generate_figure()

# %% [markdown]
# ## Supplementary Figure 14
#
# Examples of PTMs impacted by ESRP1-regulated splicing in prostate cancer, broken down by annotated function.
#
# [Return to Table of Contents](#table-of-contents)

# %%
sfig14 = generate_figures.SupplementaryFigure14(data)

# %% [markdown]
# ### Panel A

# %%
sfig14.PanelA()

# %% [markdown]
# ### Panel B

# %%
sfig14.PanelB()

# %% [markdown]
# ### Panel C

# %%
sfig14.PanelC()

# %% [markdown]
# ### Panel D

# %%
sfig14.PanelD()

# %% [markdown]
# ## Supplementary Figure 15
#
# PTMs that regulated by ESRP1 across different cancer types.
#
# [Return to Table of Contents](#table-of-contents)

# %%
sfig15 = generate_figures.SupplementaryFigure15(data)
sfig15.generate_figure()

# %% [markdown]
# ## Supplementary Figure 16
#
# Kinases whose substrates are enriched among ESRP1-regulated PTMs.
#
# [Return to Table of Contents](#table-of-contents)

# %%
sfig16 = generate_figures.SupplementaryFigure16(data)

# %% [markdown]
# ### Panel A

# %%
sfig16.PanelA()

# %% [markdown]
# ### Panel B

# %%
sfig16.PanelB()
